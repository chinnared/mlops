# %%
from src.config import DATA_PATH, RAW_TABLE
from src.data_utils import read_csv, save_table

df = read_csv(spark, DATA_PATH)

df = df.dropna()

save_table(df, RAW_TABLE)

print("Ingest Data : Completed")
