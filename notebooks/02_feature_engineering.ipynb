# %%
from src.config import RAW_TABLE, FEATURE_TABLE
from src.features import build_features

df = spark.table(RAW_TABLE)

df = build_features(df)

df.write.mode("overwrite").saveAsTable(FEATURE_TABLE)

print("Feature Engineering: Features created")
